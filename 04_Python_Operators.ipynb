# %% [markdown]
# # Operators in Python

# %% [markdown]
# ## What are Operators in Python?
# ### Operators are symbols that perform operations on values and variables.

# %% [markdown]
# Operators are symbols which are used to perform a specific operation between values.
#
# 1. Arithmetic operators
# 2. Comparison operators
# 3. Assignment operators
# 4. Logical operators
# 5. Bitwise operators
# 6. Membership operators
# 7. Identity operators

# %% [markdown]
# # 1. Arithmetic Operators + _ * / // ** %
# ## Used for mathematical calculations.

# %%
 Operator:  Meaning: Example
+   Addition	(5 + 3)
-	Subtraction	(5 - 3)
*	Multiplication	(5 * 3)
/	Division	(5 / 3)
//	Floor Division	(5 // 3)
%	Modulus (Remainder)	(5 % 3)
**	Power (5 **3 )

# %%
# Notes
12+5
12,5 =operand, 
 "+" =operators

# %%
5+"5"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 5+"5"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## 1.Addition (+)
# Adds numbers.

# %%
667+765
# Out:
# 1432

# %%
a =10
b =5
print(a + b)
# Out:
# 15

# %%
a=8
b=6
c=3
print(a+b+c)
# Out:
# 17

# %% [markdown]
# ## 2. Subtraction (-)
# Subtracts one number from another.

# %%
197-67
# Out:
# 130

# %%
a = 10
b = 5
print(a - b)

# %%
a = 38
b = 12
c = 8
print(a-b-c)
# Out:
# 18

# %% [markdown]
# ## 3. Multiplication (*)
# Multiplies two numbers.

# %%
6*12
# Out:
# 72

# %%
a = 10
b = 5
print(a * b)
# Out:
# 50

# %%
a = 8
b = 12
c = 19
print(a*b*c)
# Out:
# 1824

# %% [markdown]
# ## 4. Division (/)
# Divides one number by another and returns a decimal result.

# %%
24/6
# Out:
# 4.0

# %%
a = 10
b = 5
print(a / b)
# Out:
# 2.0

# %% [markdown]
# ## 5.Floor division (//)
# To get round off value ,value before the decimal.

# %%
print(5/2)
print(5//2)
# Out:
# 2.5
# 2

# %%
print(12/7)
print(12//7)
# Out:
# 1.7142857142857142
# 1

# %%
print(3/2)
print(3//2)
# Out:
# 1.5
# 1

# %%
print(10/3)
print(10//3)
# Out:
# 3.3333333333333335
# 3

# %%
print(12.5/4)
print(12.5//4)
# Out:
# 3.125
# 3.0

# %%
print(15/5.2)
print(15//5.2)
# Out:
# 2.8846153846153846
# 2.0

# %%
print(8.2/2.2)
print(8.2//2.2)
# Out:
# 3.7272727272727266
# 3.0

# %% [markdown]
# ## 6. Exponentiation ** (powers)

# %%
print(2**2)
print(3**2)
print(4**2)
print(5**4)
# Out:
# 4
# 9
# 16
# 625

# %%
print(2*2*2)
print(2**3)
# Out:
# 8
# 8

# %% [markdown]
# ## 7.Modulo operation %- (Give remainder)

# %%
print(5%2)
print(3%2)
print(7%3)
print(20%3)
# Out:
# 1
# 1
# 1
# 2

# %%
5%2
# Out:
# 1

# %%
12%2
# Out:
# 0

# %%
13%3
# Out:
# 1

# %%
9%7
# Out:
# 2

# %%
17%5
# Out:
# 2

# %%
x=5
y=2
print(x%y)
# Out:
# 1

# %%
x=39
y=5
print(x%y)
# Out:
# 4

# %% [markdown]
# # 2. Comparison operators (== != >< >= <=)
# ## Comparison operators allow to compare value. They give result as either True or False
# ### (==) true(when both values are equal)output=True

# %%
   (!) not
  (!=) not equal to (when both values are not equal)output=True
  (<=) less than or equal to
  (>=) greater than or equal to
  (<) less than
  (>) greater than

# %%
x=78
y=10

# %%
x==y
# Out:
# False

# %%
x<y
# Out:
# True

# %%
x>y
# Out:
# False

# %%
x>=y
# Out:
# False

# %%
x<=y
# Out:
# True

# %%
a=4
b=7

# %%
a==b
# Out:
# False

# %%
a>=b
# Out:
# False

# %%
b>a
# Out:
# True

# %%
a=90
b=90

# %%
a==b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
(2**2)+(5**2)*(3**2)
# Out:
# 229

# %%
x=90
y=30
print(x==y)
print(x!=y)
# Out:
# False
# True

# %%
x=89
y=89
print(x==y)
print(x!=y)
# Out:
# True
# False

# %%
p=90
q=78
print(p>=q)
# Out:
# True

# %% [markdown]
# # 3. Logical operators
#  ## It is used to combine conditional statements
#  ## "and" = true comes when both conditional are true
#  ## (and ,or ,not)

# %%
a=6
a>8 and a<15
# Out:
# False

# %%
a=9
a>8 and a<15
# Out:
# True

# %%
a=17
a>8 and a<15
# Out:
# False

# %%
a=9
a>8 and a<15
# Out:
# True

# %%
a<15
# Out:
# True

# %%
a=7
a>8 and a<15

# %%
x=10
y=12

x<y and x!=10
# Out:
# False

# %%
x<y
# Out:
# True

# %%
x!=10
# Out:
# False

# %%
x=7
y=12

x<y and x!=10
# Out:
# True

# %%
x=10
y=9

x<y and x!=10
# Out:
# False

# %%
x>y and x!=15
# Out:
# True

# %% [markdown]
# # "Or" when one condition is true the output is true

# %%
x=15
y=9

x<y or x!=10
# Out:
# True

# %%
x=10
y=90

x<y or x!=10
# Out:
# True

# %%
x=10
y=5

x<y or x!=10
# Out:
# False

# %%
x=7
y=50

x<y or x!=10
# Out:
# True

# %%
x=20
y=90

x>y or x!=10
# Out:
# True

# %%
x>y
# Out:
# False

# %%
x!=10
# Out:
# True

# %% [markdown]
#  ## and = aur
#  ## or = ya

# %% [markdown]
# # Not

# %%
x=45
x>20
# Out:
# True

# %%
not x>20
# Out:
# False

# %%
x=15
x>20
# Out:
# False

# %%
not x>20
# Out:
# True

# %%
a=45
b=44
c=4
a>34 and b!=44 and c>5
# Out:
# False

# %%
a>34
# Out:
# True

# %%
b!=44
# Out:
# False

# %%
c>5
# Out:
# False

# %%
a<34 and a!=45 and b==5
# Out:
# False

# %%
a<b and a!=c and b==c
# Out:
# False

# %%
a<b or a!=c or b==c
# Out:
# True

# %%
a<b or a!=c and b==c
# Out:
# False

# %%
a<b
# Out:
# False

# %%
a!=c
# Out:
# True

# %%
b==c
# Out:
# False

# %%
a<b and a!=c or b==c
# Out:
# False

# %%
not a<b
# Out:
# True

# %%
not a!=c
# Out:
# False

# %%
 not b==c
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
not a<=b
# Out:
# True

# %%
a>=4
# Out:
# True

# %%
a>=90
# Out:
# False

# %%
a>=b
# Out:
# True

# %% [markdown]
# # And / Or / Not

# %%
x=90
x>100 and x<80
# Out:
# False

# %%
x>100 or x<120
# Out:
# True

# %%
not x>100
# Out:
# True

# %%
a=True
b=False
print(a and b)
print(a or b)
print( not a)
# Out:
# False
# True
# False

# %%
a=True
b=False
pr

# %%
a=5
b=3
print(a>=b)
print(a!=b)
print(a==b)
print(a>b)
print(a<b)
# Out:
# True
# True
# False
# True
# False

# %%
a=8
b=9
a>b or a>5 or b<10
# Out:
# True

# %% [markdown]
# # 4. Identity Operators = is , is not
# ## Check whether two variable share the same memory location or not.

# %%
x=12
id(x)
# Out:
# 140711978116360

# %%
print(id(x))
# Out:
# 140711978116360

# %%
y=12
id(y)
# Out:
# 140711978116360

# %%
print(id(y))
# Out:
# 140711978116360

# %%
a=[87]
b=[87]
print(id(a))
print(id(b))
# Out:
# 1163065315840
# 1163111307072

# %%
(x is y)
# Out:
# True

# %%
(a is b)
# Out:
# False

# %%
x=10
y=10
print(id(x))
print(id(y))
print(x is y) # memory location check
print(x is not y)
print(x==y) # value
print(x!=y)
# Out:
# 140711978116296
# 140711978116296
# True
# False
# True
# False

# %%
x=[12]
y=[12]
print(id(x))
print(id(y))
print(x is y)
print(x is not y)
print(x==y)
# Out:
# 1163111316544
# 1163111306496
# False
# True
# True

# %%
x=[19]
y=[18]
print(id(x))
print(id(y))
print(x is y)
print(x is not y)
print(x == y)
# Out:
# 1163111360128
# 1163111356160
# False
# True
# False

# %%
x=12
y=13
print(id(x))
print(id(y))
print(x is y)
print(x==y)
# Out:
# 140711978116360
# 140711978116392
# False
# False

# %%
x="hello world"
y="world"
print(id(x))
print(id(y))
print(x is y)
print(x is not y)
print(y in x)
print(y not in x)
# Out:
# 1163117508528
# 1163112667184
# False
# True
# True
# False

# %%
a="value"
b="value"
print(id(a))
print(id(b))
print(a is b)
print(a==b)
# Out:
# 140711978174944
# 140711978174944
# True
# True

# %%
a=8
b=9
print(a is b)
print(b is a)
# Out:
# False
# False

# %%
a=12
b=12
print(a is b)
print(b is a)
# Out:
# True
# True

# %%
a=45
b=45
print(id(a))
print(id(b))
print(a is b)
print(a is not b)
# Out:
# 140711978117416
# 140711978117416
# True
# False

# %% [markdown]
# ## memory location of a and b is same =(a is b) True
# ## memory location of a and b is different =(a is not b) False

# %%
a=90
b=89
print(id(a))
print(id(b))
print(a is b)
print(a is not b)
# Out:
# 140711978118856
# 140711978118824
# False
# True

# %% [markdown]
# # 5. Membership Operators (in, not in)

# %%
# Sequence data type( multiple data(values) store)
1. List = [12,89,32,234,"Hello"]
2. String = "HELLO"
3. Tuple
4. Set
5. Dictionary

# Non Sequence data type (single value store)
1. Integers 
2. Float
3. Boolen

# %%
x=195
y=[289,"vijAI",195,357.94]
print(x in y)
print(x not in y)
# Out:
# True
# False

# %%
z=44
print(z in y)
print(z not in y)
# Out:
# False
# True

# %%
z="Robotics"
print(z in y)
print(z not in y)
# Out:
# False
# True

# %%
a="vijAI Robotics"
b="x"
print(b in a)
print(b not in a)
# Out:
# False
# True

# %%
x="Hello"
y="l"
print(y in x)
print(y not in x)
# Out:
# True
# False

# %%
x=90
z=[67,65,23,45,90]
print(x in z)
print(x not in z)
# Out:
# True
# False

# %%
p=780
q=8
print(q in p)
print(q not in p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 p=780
#       2 q=8
# ----> 3 print(q in p)
#       4 print(q not in p)
#
# TypeError: argument of type 'int' is not iterable

# %%
p=4,3,3
q=3
print(q in p)
print(q not in p)
# Out:
# True
# False

# %%
batch1=5.5
batch2=5
print(batch2 in batch1)
print(batch2 not in batch1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 3
#       1 batch1=5.5
#       2 batch2=5
# ----> 3 print(batch2 in batch1)
#       4 print(batch2 not in batch1)
#
# TypeError: argument of type 'float' is not iterable

# %%
std=1.2,3.4,5.6,9.0
std2=9.0
print(std2 in std)
print(std2 not in std)
# Out:
# True
# False

# %%
std2=87
print(std2 in std)
print(std2 not in std)
# Out:
# False
# True

# %%
value=[5,5,3,2,9]
value1=5
print(value1 in value)
print(value1 not in value)
# Out:
# True
# False

# %%
a="hello"
b="hel"
print(b in a)
# Out:
# True

# %%
a="hello"
b="ho"
print(b in a)
# Out:
# False

# %%
a="Hello"
b="olleH"
print(b in a)
# Out:
# False

# %% [markdown]
# # 6. Assignment Operator

# %% [markdown]
# ## Assignment operator assign value to variables  +=,-=,*=,/=,%=,**=,//=,
# ## ( Bitwise  |=,&=,^=,>>=,~=,<<=)

# %%
x+=9
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x+=9
#       2 print(x)
#
# NameError: name 'x' is not defined

# %%
x=5
x+=9 # x=x+9
x
# Out:
# 14

# %%
x
# Out:
# 14

# %%
y=15
y
# Out:
# 15

# %%
y+9 #y+=9
# Out:
# 21

# %%
x-=6
x
# Out:
# 14

# %%
y-=1
y
# Out:
# 12

# %%
x=7
x
# Out:
# 7

# %%
x-=5
x
# Out:
# -13

# %%
x
# Out:
# -13

# %%
z=9
z
# Out:
# 9

# %%
z*=3
z
# Out:
# 81

# %%
str=10
str
# Out:
# 10

# %%
str*=2
str
# Out:
# 40

# %%
str*2
# Out:
# 80

# %%
str1=5
str1
# Out:
# 5

# %%
str1*=2
str1
# Out:
# 10

# %%
std=10
std
# Out:
# 10

# %%
std-=5
std
# Out:
# -10

# %%
std1=10
std1
# Out:
# 10

# %%
std1/=2
std1
# Out:
# 5.0

# %%
std1/=5
std1
# Out:
# 0.2

# %%
a=5
a
# Out:
# 5

# %%
a**=2
a
# Out:
# 625

# %%
b=2
b
# Out:
# 2

# %%
b**=2
b
# Out:
# 4

# %%
z=100
print(z)
z**=2
print(z)
# Out:
# 100
# 10000

# %%
p=69
p
# Out:
# 69

# %%
p//=5
p
# Out:
# 13

# %%
q=19
q
# Out:
# 19

# %%
q//=3
q
# Out:
# 6

# %% [markdown]
# # 7. Bitwise Operators & | ^ ~ << >>
# ### & - Bitwise AND
# ### | - Bitwise OR
# ### ^ - Bitwise XOR
# ### ~ - Bitwise NOT
# ### << - Left Shift
# ### >> - Right Shift

# %%
"Hello
world"
# Out:
#   Cell In[81], line 1
#     "Hello
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"""hello 
 world"""
# Out:
# 'hello \n world'

# %%
"""a
 b
 c"""
# Out:
# 'a\n b\n c'

# %%
'''hello
 preety
 girl'''
# Out:
# 'hello\n preety\n girl'

# %%
""hello 
world""
# Out:
#   Cell In[88], line 1
#     ""hello
#       ^
# SyntaxError: invalid syntax

# %%
value=35
value
# Out:
# 35

# %%
value=35+9
value
# Out:
# 44

# %%
value
# Out:
# 44

# %%
value+6
# Out:
# 50

# %%
value
# Out:
# 44

# %%
value+=12
value
# Out:
# 56

# %%
print(value*2)
print(value)
# Out:
# 112
# 56

# %%
a = "Python"
b = "3"
print(a+b*2)
# Out:
# Python33

# %%
value=10/2*3
print(value)
# Out:
# 15.0

# %%
x=5
print(x>3 and x<10)
# Out:
# True

# %%
2*2**2*2*2
# Out:
# 32

# %%
message="Hello"
print('el' in message)
print('Ho' in message)
# Out:
# True
# False

# %%
x=[1,2,3]
y=[1,2,3]
print(x == y)
print(x is y)
# Out:
# True
# False

# %%
x=10
y=50
z=x>100 and y<100:
print(x,y)
# Out:
#   Cell In[26], line 3
#     z=x>100 and y<100:
#                      ^
# SyntaxError: invalid syntax

# %%
a=[10,20]
b=a
b+=[30,40]
print(a)
print(b)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
x=10
y="2"
print(x+int(y))
# Out:
# 12

# %%
x=100
y=50
print(x and y)
# Out:
# 50
