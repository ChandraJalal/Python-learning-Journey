# %% [markdown]
# # Type casting

# %% [markdown]
# Converting one data type into another

# %%
x=45
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
x=int(x)
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
y=12
print(y)
print(type(y))
# Out:
# 12
# <class 'int'>

# %%
y=float(y)
print(y)
print(type(y))
# Out:
# 12.0
# <class 'float'>

# %%
a="pynative"
print(a)
print(type(a))
# Out:
# pynative
# <class 'str'>

# %%
a=90
print(a)
print(type(a))
# Out:
# 90
# <class 'int'>

# %%
a=float(a)
print(a)
print(type(a))
# Out:
# 90.0
# <class 'float'>

# %%
a
# Out:
# '90'

# %%
b=8.4
print(b)
print(type(b))
# Out:
# 8.4
# <class 'float'>

# %%
b=int(b)
print(b)
print(type(b))
# Out:
# 8
# <class 'int'>

# %%
b=bool(b)
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %%
print(b)
print(a)
# Out:
# True
# 90.0

# %%
a=float(a)
print(a)
print(type(a))
# Out:
# 90.0
# <class 'float'>

# %%
a=str(a)
print(a)
print(type(a))
# Out:
# 90
# <class 'str'>

# %% [markdown]
# Functions
# 1.int()
# 2.float()
# 3.str()
# 4.bool()
