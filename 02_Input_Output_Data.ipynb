# %% [markdown]
# # Input & Output in python

# %% [markdown]
# In this notebook, we wil learn:
# - print()
# - input()
# - User Input
# - Type Conversion

# %% [markdown]
# ## 1. Output using print()

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## 2. Taking Input fom User

# %%
name = input("Enter your name:")
print("Hello", name)
# Out:
# Enter your name: Tanuja
# Hello Tanuja

# %% [markdown]
# ## 3. Input Always Returns String

# %%
age = input("Enter your age:")
print(type(age))
# Out:
# Enter your age: 21
# <class 'str'>

# %% [markdown]
# ## 4. Type Conversion

# %%
age = int(input("Enter your age:"))
print(type(age))
# Out:
# Enter your age: 21
# <class 'int'>

# %% [markdown]
# ## 5. Addition of Two Numbers

# %%
num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))

print("Sum =",num1 + num2)
# Out:
# Enter first number: 5
# Enter second number: 10
# Sum = 15

# %% [markdown]
# # Mini Project by using input

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))

print("My name is", name)
print("I am", age, "years old")
# Out:
# Enter your name: Tanuja
# Enter your age: 23
# My name is Tanuja
# I am 23 years old

# %% [markdown]
# ## Tea stall

# %%
#phase 1- Tea stall,k

stall_name="Tea stall"
tea_price=20
tea_available=50
print("Welcome to",stall_name)
cups=int(input("How many tea cups do you want?"))
bill=cups*tea_price
print("Total Bill is Rs.",bill)
remaining_tea=tea_available-cups
print("Tea cups reamining:",remaining_tea)
# Out:
# Welcome to Tea stall
# How many tea cups do you want? 2
# Total Bill is Rs. 40
# Tea cups reamining: 48

# %% [markdown]
# ## Simple Calculator

# %%
num1=float(input("Enter first number:"))
num2=float(input("Enter second number:"))

operation=input("Choose operation(+,-,*,/):")

if operation=="+":
   print("Result=",num1+num2)

elif operation=="-":
   print("Result=",num1-num2)

elif operation=="*":
   print("Result=",num1*num2)

elif operation=="/":
   print("Result=",num1/num2)

else:
   print("Invalid operation")
# Out:
# Enter first number: 23
# Enter second number: 34
# Choose operation(+,-,*,/): -
# Result= -11.0

# %% [markdown]
# ## Conclusion

# %% [markdown]
# I learned:
# - print()
# - input()
# - User Input
# - Type Conversion
